# %% [markdown]
# # M4 — Profilage des segments
#
# Identifier les caractéristiques et préférences de chaque segment issu de M3 (personas).

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import pandas as pd

# Charger le résultat de M3 (à exporter depuis M3, ex: features.to_csv("../data/processed/segments.csv"))
# segments = pd.read_csv("../data/processed/segments.csv")

# %% [markdown]
# ## Statistiques par segment

# %%
# segments.groupby("Cluster").agg(["mean", "count"])

# %% [markdown]
# ## Personas
#
# Pour chaque cluster, décrire : profil démographique dominant, comportement d'achat, canal préféré, produits favoris.
