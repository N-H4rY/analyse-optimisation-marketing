# %% [markdown]
# # M2 — Exploration des données
#
# Nettoyage, visualisation et résumé des données clients, produits et ventes.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_customers, load_products, load_sales

customers = load_customers()
products = load_products()
sales = load_sales()

# %% [markdown]
# ## Aperçu et qualité des données

# %%
for name, df in [("customers", customers), ("products", products), ("sales", sales)]:
    print(name, df.shape)
    display(df.head())
    display(df.isna().sum())
# Out:
# customers (5, 7)
#    Customer_ID     Name  Age  Gender     Location  Join_Date  Total_Spent
# 0         2001    Alice   28  Female     New York 2022-05-10        500.0
# 1         2002      Bob   35    Male  Los Angeles 2022-06-15        750.0
# 2         2003  Charlie   22    Male      Chicago 2022-07-20        300.0
# 3         2004    Diana   30  Female      Houston 2022-08-25        600.0
# 4         2005      Eva   27  Female      Phoenix 2022-09-30        450.0
# Customer_ID    0
# Name           0
# Age            0
# Gender         0
# Location       0
# Join_Date      0
# Total_Spent    0
# dtype: int64
# products (5, 5)
#    Product_ID Product_Name     Category  Price    Brand
# 0         101      T-shirt     Clothing   25.0  Brand A
# 1         102        Jeans     Clothing   75.0  Brand B
# 2         103     Sneakers     Footwear   30.0  Brand C
# 3         104       Jacket    Outerwear  120.0  Brand D
# 4         105          Hat  Accessories   22.5  Brand E
# ...

# %% [markdown]
# ## Visualisations exploratoires

# %%
customers["Total_Spent"].plot(kind="hist", title="Distribution des dépenses clients")
plt.show()
